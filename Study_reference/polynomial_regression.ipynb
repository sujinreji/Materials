# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

# %%
X = np.linspace(0, .5,100)
X.shape
# Out:
# (100,)

# %%
y_actual = np.cos(2*np.pi*X)**2
y_actual.shape
# Out:
# (100,)

# %%
plt.plot(X,y_actual)

# %%
noise = np.random.normal(0,0.1,100)
print(noise)
# Out:
# [-0.10934734  0.01166733 -0.0505928  -0.06243316 -0.0455865   0.09429223
#   0.10361889 -0.08089618 -0.05136714 -0.08201807  0.02058405 -0.00488742
#   0.14652764 -0.1129551   0.16813159 -0.00249118 -0.02112677 -0.03576881
#  -0.16727574 -0.09885977  0.24816895 -0.07199688  0.02622001 -0.03952864
#   0.07519709 -0.13022599  0.09676792 -0.1517463  -0.13177821 -0.13244512
#  -0.06946289  0.01668961  0.07930252 -0.06849735 -0.01506176  0.14790671
#  -0.06729111 -0.23585144  0.04881043 -0.01805229 -0.04082312 -0.08892193
#   0.18637267  0.01110547 -0.04095806 -0.00557121  0.01411399  0.01552893
#   0.03532052 -0.06369795 -0.1268871   0.06359797  0.08710082  0.06466553
#   0.09595139 -0.0288459  -0.01697036 -0.08342096  0.04209199 -0.01421087
#   0.03673574  0.05469264  0.22663291 -0.0941938  -0.06684474  0.05772864
#  -0.01138344  0.00629435 -0.10735713  0.10339447  0.08411504  0.12729139
#  -0.04917045 -0.03541631 -0.06039959 -0.05586461  0.1130981  -0.00860747
#  -0.00546722 -0.07681816  0.06085671  0.04716338  0.04472425 -0.04738153
#   0.17424315 -0.05697392 -0.01461372  0.10155332 -0.02980384  0.08378362
#   0.04219502  0.03566869  0.14631092 -0.0821822  -0.06914279 -0.07632161
#   0.03822398 -0.05752177  0.15651568 -0.17558561]

# %%
y = y_actual + noise 
print(y)
# Out:
# [ 0.89065266  1.01066067  0.94538461  0.92853119  0.93838785  1.06932779
#   1.06780286  0.87056709  0.88555755  0.83860869  0.92321918  0.8781348
#   1.00839466  0.7262996   0.98340792  0.78753728  0.74248596  0.70036673
#   0.54043177  0.57958334  0.89662914  0.54588258  0.6130441   0.51589046
#   0.59898805  0.36184103  0.55714294  0.27709628  0.26581845  0.23431798
#   0.26700313  0.32351705  0.35726922  0.18150265  0.20797821  0.34510187
#   0.10527852 -0.08658889  0.17617821  0.08892116  0.04733859 -0.01791364
#   0.24195494  0.05305124 -0.01080437  0.0146823   0.0263991   0.02180949
#   0.03758456 -0.06344622 -0.12663537  0.06586201  0.09338137  0.07695064
#   0.1162049   0.00130779  0.02497541 -0.02783869  0.11310028  0.07395084
#   0.14370919  0.18206042  0.37589546  0.07837583  0.13035041  0.28076861
#   0.23861656  0.28426104  0.1994703   0.43986049  0.45087813  0.52488805
#   0.37967213  0.42495871  0.43166742  0.46792635  0.6685172   0.57821662
#   0.61241224  0.57164202  0.73929982  0.75487089  0.78085979  0.7162312
#   0.96427161  0.75830241  0.82464099  0.96342034  0.85321838  0.98641874
#   0.96282178  0.97259338  1.09777419  0.88200177  0.90589277  0.90765274
#   1.02918833  0.93845564  1.15550902  0.82441439]

# %%
plt.plot(X,y,color="red")
plt.plot(X,y_actual,color="blue")

# %%
model = linear_model.LinearRegression(fit_intercept=True)

# %%
X=X.reshape(-1,1)
y=y.reshape(-1,1)

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
plt.plot(X,y_actual,color="blue")
plt.scatter(X,y,color="red")
plt.plot(X,y_pred,color="green")

# %%
deg = 2
scalar = StandardScaler()
polynomial_features = PolynomialFeatures(degree=deg,include_bias=True)
linear = linear_model.LinearRegression(fit_intercept=True)
pipeline = Pipeline([("polynomial", polynomial_features),("scaling",scalar),("linear",linear)])

# %%
pipeline.fit(X,y)
# Out:
# Pipeline(steps=[('polynomial', PolynomialFeatures()),
#                 ('scaling', StandardScaler()), ('linear', LinearRegression())])

# %%
y_pred = pipeline.predict(X)

# %%
plt.plot(X,y_actual,color="blue")
plt.scatter(X,y,color="red")
plt.plot(X,y_pred,color="green")

# %%
deg = 10000
# scalar = StandardScaler()
polynomial_features = PolynomialFeatures(degree=deg,include_bias=True)
linear = linear_model.LinearRegression(fit_intercept=True)
pipeline = Pipeline([("polynomial", polynomial_features),("linear",linear)])
pipeline.fit(X,y)
y_pred = pipeline.predict(X)
plt.plot(X,y_actual,color="blue")
plt.scatter(X,y,color="red")
plt.plot(X,y_pred,color="green")
